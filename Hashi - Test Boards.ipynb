# %% [markdown]
# ## 5 x 5

# %%
# 5A

P = [(0,0),(0,1),(0,3),(2,1),(2,3),(4,0),(4,1),(4,4)]
L = [1,2,2,4,3,2,5,1]
k = len(P)
m = 5
n = 5

# %%
# 5B

P = [(0,0),(0,1),(0,3),(0,4),(2,0),(2,1),(2,4),(3,1),(3,3),(3,4),(4,4)]
L = [1,5,3,1,2,8,3,4,2,2,1]
k = len(P)
m = 5
n = 5

# %%
# 5C

P = [(0,0),(0,1),(0,3),(2,1),(4,1),(4,3),(4,4)]
L = [1,3,2,2,3,5,2]
k = len(P)
m = 5
n = 5

# %% [markdown]
# ## 7 x 7

# %%
# 7A
P = [(0,0), (0,3), (0,5), (2, 2), (2, 5), (4, 0), (4, 2), (4, 6), (6, 0), (6, 2), (6, 4), (6, 6)]
L = [4,4,2,4,2,5,7,2,3,4,1,2]
k = len(P)
m = 7
n = 7

# %%
# 7B
P = [(0, 0), (0, 5), (2, 5), (3, 0), (3, 6), (4, 2), (4, 5), (6, 0), (6, 2),(6, 6)]
L = [2,2,1,3,2,4,2,1,4,3]
k = len(P)
m = 7
n = 7

# %%
# 7C
P = [(0,0), (0, 6), (1, 1), (1, 4), (3,0), (3,4), (4, 1), (4, 3), (4,6), (5,0), (6, 1), (6, 4), (6,6)]
L = [2,3,2,4,4,5,3,1,3,1,3,3,2]
k = len(P)
m = 7
n = 7

# %%
# 7D
P = [(0,1), (0, 4), (0, 6), (1,0), (1,3), (2,1), (2,6), (3,0), (3,3), (5, 1), (5, 3), (6, 0), (6,4), (6,6)]
L = [3,3,1,2,1,2,2,4,4,2,4,2,3,3]
k = len(P)
m = 7
n = 7

# %%
# 7E
P = [(0,0), (0,2), (0,4), (0,6), (1,1), (2, 6), (3,0), (3,2), (4,1), (4, 4), (4,6), (6, 1), (6,4), (6,6)]
L = [4,6,4,2,2,1,2,2,5,6,1,1,3,1]
k = len(P)
m = 7
n = 7

# %% [markdown]
# ## 10 x 10

# %%
# 10A
P = [(0,0), (0,2), (0,9), (2, 0), (2, 3), (2,5), (2,8), (4, 0), (4, 2), (4,5), (4, 7), (6, 0), (6,3), (6,5), (6,8), (7,4), (8,3),(8,5),(8,7),(8,9),(9,0), (9,2),(9,4),(9,6),(9,8)]
L = [3,4,3,2,2,6,2,4,6,6,2,4,3,5,3,1,2,3,1,1,3,5,3,1,3]
k = len(P)
m = 10
n = 10

# %%
# 10B
P = [(0,0),(0,2),(0,6),(0,9),(1,3),(1,5),(1,7),(2,9),(3,0),(4,5),(4,9),(5,0),(5,3),(5,6),(6,7),(6,9),(8,3),(8,6),(8,8),(9,0),(9,2),(9,9)]
L = [1,4,3,3,3,4,1,4,2,2,4,3,3,5,2,5,2,6,2,2,4,3]
k = len(P)
m = 10
n = 10

# %%
# 10C
P = [(0,0),(0,2),(0,4),(0,7),(0,9),(2,0),(2,9),(3,2),(4,5),(4,7),(5,0),(5,3),(6,7),(7,2),(7,4),(7,9),(9,0),(9,4),(9,6),(9,9)]
L = [3,5,3,4,3,1,3,2,1,4,2,1,2,2,7,5,2,3,1,2]
k = len(P)
m = 10
n = 10

# %%
# 10D
P = [(0,1),(0,3),(0,5),(0,9),(1,0),(2,3),(2,6),(2,9),(3,0),(3,5),(3,7),(4,1),(4,3),(4,9),(6,1),(6,7),(7,0),(7,3),(7,5),(8,7),(9,0),(9,5),(9,9)]
L = [2,1,3,3,2,2,1,5,3,4,2,4,4,4,4,4,2,2,3,2,1,5,3]
k = len(P)
m = 10
n = 10

# %%
# 10E
P = [(0,1),(0,6),(0,8),(1,7),(2,0),(2,5),(2,9),(3,3),(3,7),(5,0),(5,3),(5,6),(5,9),(6,2),(6,4),(6,8),(8,0),(8,2),(8,4),(8,6),(8,8),(9,1),(9,3),(9,7),(9,9)]
L = [1,4,3,2,2,1,1,1,4,3,5,3,3,2,1,3,2,3,3,3,2,2,5,4,3]
k = len(P)
m = 10
n = 10

# %% [markdown]
# ## 15 x 15

# %%
# 15B

P = [(0,0),(0,13),(1,14),(2,0),(2,13),(4,2),(4,5),(4,9),(4,13),(6,2),(6,4),(6,6),(6,9),(6,11),(6,13),(7,0),(7,5),(7,14),
    (8,1),(8,3),(9,6),(9,14),(10,0),(10,3),(11,6),(11,13),(13,0),(13,3),(13,6),(13,13),(14,1),(14,5),(14,14)]
L = [4,4,1,5,3,2,4,5,2,3,2,1,4,2,1,6,7,4,2,3,3,3,6,3,5,4,3,1,2,3,1,4,3]
k = len(P)
m = 15
n = 15

# %%
# 15C 
P = [(0,0), (0,4),(0,12), (1,2), (1,14), (2,6),(2,10),(4,6),(4,8),(4,10),(4,14),
    (5,2),(5,4),(6,8),(7,0),(7,6),(7,10),(8,2),(8,12),(9,3),(9,5),(9,9),(9,11),
    (12,3), (12,9),(12,11),(13,2),(13,5),(13,12),(13,14),(14,0),(14,6),(14,10)]
L = [4,5,3,1,1,3,1,3,3,3,2,3,4,1,4,4,3,4,6,4,6,6,3,2,3,2,2,3,5,3,3,4,2]
k = len(P)
m = 15
n = 15

# %%
# 15D

I = [(0,0),(0,8),(0,14),(1,1),(1,9),(1,13),(2,7),(2,12),(2,14),(3,2),(3,5),(3,11),
    (5,1),(5,5),(5,7),(5,11),(6,2),(8,3),(8,5),(9, 14),(10,3),(13,0),(13,2),(13,5),
    (13,7),(13,11),(14,1),(14,12),(14,14)]
L = [3,3,3,3,2,1,1,4,3,1,4,1,5,7,5,3,1,3,4,2,2,2,3,6,6,4,3,4,1]
k = len(I)
m = 15
n = 15

# %%
# 15E
P = [(0,0),(0,2),(0,6),(0,12),(0,14),(2,0),(2,2),(2,11),(4,0),(5,3),(5,6),
    (7,0),(8,6),(8,11),(9, 3),(10,0),(10,2),(10,12),(10,14),(11,1),(12,2),
    (13,1),(13,12),(14,0),(14,2),(14,14)]
L = [1,4,2,3,4,3,6,2,2,2,3,2,3,4,1,5,8,4,3,2,2,3,2,3,2,2]
k = len(P)
m = 15
n = 15

# %% [markdown]
# ## 25 x 25

# %%
# 25A

I = [(0,8),(0,24),(1,0),(1,5),(2,3),(2,9),(2,12), (2,17),(2,24),(3,0),(3,2),
    (4,6),(4,8),(4,12),(4,18),(6,2),(6,5),(6,24),(7,1),(7,3),(8,6), (8, 17),(8, 23),
    (10, 7),(10,9),(10,17),(10,24),(11,6),(11,16),(12,18),(12, 24),(13,1),(13,6),
    (13,14),(13,16),(14,18),(14,21),(15,6),(15,17),(15,24),(16,7),(16,18),(16,20),(16,23),
    (17,6),(18,7),(18,18),(18,21),(18,23),(19,1),(20,18),(20,20),(20,24),(21,1),
    (22, 7),(22,17),(22,24),(23,1),(23,3),(23,5),(23,22),(24,0),(24,24)]
L = [2,2,3,3,1,1,3,1,4,4,3,2,4,4,1,2,4,5,2,4,4,4,1,2,3,5,6,3,1,3,4,2,3,4,2,3,2,5,5,3,2,2,4,3,2,3,1,1,3,1,2,6,5,1,3,4,3,3,5,3,1,3,3]
k = len(I)
m = 25
n = 25

# %%
# 25B

P = [(0,0),(0,2),(0,4),(0,24),(2,0),(2,8),(2,10),(2,12),(2,14),(2,17),(2,20),(2,22),
    (3,2),(4,5),(4,7),(4,14),(4,24),(5,10),(6,2),(6,7),(7,0),(7,10),(7,12),(8,2),(8,14),
    (9,0),(9,24),(10,1),(10,3),(10,23),(11,2),(11,5),(11,9),(11,16),(11,22),
    (12,1),(12,18),(12,21),(13,2),(13,16),(14,1),(15,0),(15,14),(15,16),(15,18),(15,21),
    (16,1),(16,9),(16,11),(17,0),(17,3),(17,8),(17,13),(17,19),(17,21),
    (18,2),(18,7),(19,3),(19,13),(19,16),(19,18),(19,20),(20,0),(20,2),(20,7),(20,22),
    (21,3),(21,5),(21,16),(21,20),(22,0),(22,2),(22,11),(22,14),(22,21),(22,23),
    (23,5),(23,7),(24,0),(24,3),(24,9),(24,13),(24,24)]
L = [2,3,3,3,2,2,1,1,3,3,4,2,2,2,5,6,3,1,3,2,3,3,1,2,4,3,3,3,3,3,1,1,3,5,3,
    2,1,2,3,6,1,4,5,8,6,4,2,6,4,5,5,2,1,2,3,1,1,1,3,4,3,2,2,4,4,2,2,3,3,1,
    3,3,2,4,5,4,2,1,1,4,5,4,2]
k = len(P)
m = 25
n = 25

# %% [markdown]
# # 30 x 30

# %%
# 30A

P = [(0,0),(0,5),(0,23),(0,28),(1,1),(1,3),(1,7),(1,12),(1,22),(2,0),
    (3,1),(3,7),(3,23),(3,28),(4,0),(4,3),(4,6),(4,8),(5,1),(5,10),(5,12),(5,20),(5,23),
    (6,13),(6,15),(6,24),(6,29),(7,0),(7,3),(7,6),(7,8),(7,11),(7,14),(7,16),(7,18),(7,20),(7,23),(7,26),
    (8,5),(8,17),(8,19),(8,29),(9,13),(9,15),(10,6),(10,11),(10,17),(10,27),
    (11,5),(11,15),(12,9),(12,12),(14,1),(14,3),(14,8),(14,12),(15,9),(15,11),(15,17),(15,19),
    (16,1),(16,3),(16,16),(16,20),(17,9),(17,12),(18,8),(18,13),(18,20),(18,23),(18,27),
    (19,3),(20,1),(20,8),(20,19),(21,0),(21,5),(21,7),(21,15),(21,20),(21,24),(21,26),
    (23,0),(23,2),(23,4),(23,7),(23,10),(23,13),(23,19),(23,24),(24,1),(24,5),(24,18),
    (25,0),(25,4),(25,7),(25,13),(25,15),(25,17),(25,20),(25,27),(25,29),
    (26,5),(26,8),(26,11),(26,25),(27,0),(27,3),(27,12),(27,15),(27,18),(27,20),(27,24),(27,27),(27,29),
    (28,5),(28,7),(28,10),(29,0),(29,4),(29,8),(29,11),(29,19),(29,23),(29,25),(29,27),(29,29)]
L = [2,2,5,2,1,2,4,3,2,2,5,7,8,2,1,1,1,1,2,2,5,1,4,3,1,2,3,3,5,4,4,3,2,5,4,2,4,2,
    1,2,4,5,4,2,2,1,4,3,3,1,2,6,2,6,4,5,2,1,3,1,3,4,2,3,2,2,3,4,5,2,5,1,2,3,2,
    3,6,6,3,6,4,1,3,3,2,2,1,4,4,2,1,2,1,5,5,4,3,4,1,6,8,4,1,2,3,2,3,2,2,5,2,4,2,3,1,
    3,5,2,1,3,2,4,5,4,5,2,1]
k = len(P)
m = 30
n = 30
